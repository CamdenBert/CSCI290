# %% [markdown]
# <a href="https://colab.research.google.com/github/CamdenBert/CSCI290/blob/main/GP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jhbellingrath/CS-290-Classwork/refs/heads/main/data/survey%20lung%20cancer.csv')

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
attributes=df.columns[df.columns!="LUNG_CANCER"]
attributes
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

#  entropy
def entropy(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return -np.sum(probabilities * np.log2(probabilities + 1e-9))

#  Gini
def gini(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return 1 - np.sum(probabilities ** 2)

# best attribute to split on
def calculate_best_split(X, y, impurity_measure):
    best_gain = -1
    best_attribute = None
    base_impurity = entropy(y) if impurity_measure == 'entropy' else gini(y)

    for attribute in X.columns:
        values = X[attribute].unique()
        split_impurity = 0
        for value in values:
            subset_y = y[X[attribute] == value]
            if len(subset_y) == 0:
                continue
            if impurity_measure == 'entropy':
                split_impurity += (len(subset_y) / len(y)) * entropy(subset_y)
            else:
                split_impurity += (len(subset_y) / len(y)) * gini(subset_y)

        gain = base_impurity - split_impurity
        if gain > best_gain:
            best_gain = gain
            best_attribute = attribute

    return best_attribute

#  attribute selection main
def Attribute_selection_method(task, dataset, target_variable, impurity_measure=None):
    if task not in ["regression", "classification"]:
        raise ValueError("Task must be either 'regression' or 'classification'.")

    #  features and target variable
    X = dataset.drop(columns=[target_variable])
    y = dataset[target_variable]

    if task == "classification" and impurity_measure is None:
        raise ValueError("For classification tasks, 'impurity_measure' must be specified.")

    #  best attribute based on the impurity
    best_attribute = calculate_best_split(X, y, impurity_measure)

    return best_attribute

# Load data
url = "https://raw.githubusercontent.com/jhbellingrath/CS-290-Classwork/refs/heads/main/data/survey%20lung%20cancer.csv"
df = pd.read_csv(url)

# LabelEncoder
le = LabelEncoder()

#  target variable
df["LUNG_CANCER"] = le.fit_transform(df["LUNG_CANCER"])

#  find the best attribute for classification
best_attribute = Attribute_selection_method("classification", df, "LUNG_CANCER", "entropy")
print("Best attribute according to custom method:", best_attribute)

# Compare
X = df.drop(columns=["LUNG_CANCER"])
y = df["LUNG_CANCER"]

# Iterate over all columns in X
for col in X.columns:
    if X[col].dtype == 'object':  # Check if the column is  object
        X[col] = le.fit_transform(X[col])  # Fit and transform

clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X, y)

# Get the first split attribute
first_split_attribute = X.columns[clf.tree_.feature[0]]
print("First attribute chosen by DecisionTreeClassifier:", first_split_attribute)
# Out:
# Best attribute according to custom method: AGE
# First attribute chosen by DecisionTreeClassifier: ALLERGY

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

#  entropy
def entropy(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return -np.sum(probabilities * np.log2(probabilities + 1e-9))

#  Gini impurity
def gini(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return 1 - np.sum(probabilities ** 2)

#  best attribute to split on
def calculate_best_split(X, y, impurity_measure):
    best_gain = -1
    best_attribute = None
    base_impurity = entropy(y) if impurity_measure == 'entropy' else gini(y)

    for attribute in X.columns:
        values = X[attribute].unique()
        split_impurity = 0
        for value in values:
            subset_y = y[X[attribute] == value]
            if len(subset_y) == 0:
                continue
            if impurity_measure == 'entropy':
                split_impurity += (len(subset_y) / len(y)) * entropy(subset_y)
            else:
                split_impurity += (len(subset_y) / len(y)) * gini(subset_y)

        gain = base_impurity - split_impurity
        if gain > best_gain:
            best_gain = gain
            best_attribute = attribute

    return best_attribute

#  attribute selection main
def Attribute_selection_method(task, dataset, target_variable, impurity_measure=None):
    if task not in ["regression", "classification"]:
        raise ValueError("Task must be either 'regression' or 'classification'.")

    #  features and target variable
    X = dataset.drop(columns=[target_variable])
    y = dataset[target_variable]

    if task == "classification" and impurity_measure is None:
        raise ValueError("For classification tasks, 'impurity_measure' must be specified.")

    #  best attribute based on the impurity
    best_attribute = calculate_best_split(X, y, impurity_measure)

    return best_attribute

# Load data
url = "https://raw.githubusercontent.com/jhbellingrath/CS-290-Classwork/refs/heads/main/data/survey%20lung%20cancer.csv"
df = pd.read_csv(url)

# Drop the AGE column
df = df.drop(columns=["AGE"])

#  LabelEncoder
le = LabelEncoder()

# target variable
df["LUNG_CANCER"] = le.fit_transform(df["LUNG_CANCER"])

# Apply the method
best_attribute = Attribute_selection_method("classification", df, "LUNG_CANCER", "entropy")
print("Best attribute according to custom method:", best_attribute)

# Compare with sklear
X = df.drop(columns=["LUNG_CANCER"])
y = df["LUNG_CANCER"]

# Iterate over all columns in X
for col in X.columns:
    if X[col].dtype == 'object':  # Check if the column is object
        X[col] = le.fit_transform(X[col])  # Fit and transform

clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X, y)

#  sklearn's DecisionTreeClassifier
first_split_attribute = X.columns[clf.tree_.feature[0]]
print("First attribute chosen by DecisionTreeClassifier:", first_split_attribute)
# Out:
# Best attribute according to custom method: ALLERGY
# First attribute chosen by DecisionTreeClassifier: ALLERGY

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import math

# entropy function
def entropy(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return -np.sum(probabilities * np.log2(probabilities + 1e-9))

# Gini function
def gini(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return 1 - np.sum(probabilities ** 2)

# best attribute to split on
def calculate_best_split(X, y, impurity_measure):
    best_gain = -1
    best_attribute = None
    base_impurity = entropy(y) if impurity_measure == 'entropy' else gini(y)

    for attribute in X.columns:
        values = X[attribute].unique()
        split_impurity = 0
        for value in values:
            subset_y = y[X[attribute] == value]
            if len(subset_y) == 0:
                continue
            if impurity_measure == 'entropy':
                split_impurity += (len(subset_y) / len(y)) * entropy(subset_y)
            else:
                split_impurity += (len(subset_y) / len(y)) * gini(subset_y)

        gain = base_impurity - split_impurity
        if gain > best_gain:
            best_gain = gain
            best_attribute = attribute

    return best_attribute

#  entropy for a quantitative variable
def calculate_entropy_for_age(df, target):
    overall = len(df)
    entropies = []
    feature = 'AGE'
    vals = df[feature].unique()

    for val in vals:
        entropy_value = 0

        # Left split
        left = df[df[feature] <= val][[feature, target]]
        props = left[target].value_counts(normalize=True)
        weight = len(left) / overall
        for prop in props:
            entropy_value -= weight * prop * math.log2(prop + 1e-9)

        # Right split
        right = df[df[feature] > val][[feature, target]]
        props = right[target].value_counts(normalize=True)
        weight = len(right) / overall
        for prop in props:
            entropy_value -= weight * prop * math.log2(prop + 1e-9)

        entropies.append(entropy_value)

    return entropies

# Attribute selection main
def Attribute_selection_method(task, dataset, target_variable, impurity_measure=None):
    if task not in ["regression", "classification"]:
        raise ValueError("Task must be either 'regression' or 'classification'.")

    # features and target variable
    X = dataset.drop(columns=[target_variable])
    y = dataset[target_variable]

    if task == "classification" and impurity_measure is None:
        raise ValueError("For classification tasks, 'impurity_measure' must be specified.")

    # best attribute based on the impurity
    best_attribute = calculate_best_split(X, y, impurity_measure)

    return best_attribute

# Load data
url = "https://raw.githubusercontent.com/jhbellingrath/CS-290-Classwork/refs/heads/main/data/survey%20lung%20cancer.csv"
df = pd.read_csv(url)

# LabelEncoder
le = LabelEncoder()

# target variable
df["LUNG_CANCER"] = le.fit_transform(df["LUNG_CANCER"])

# find the best attribute for classification
best_attribute = Attribute_selection_method("classification", df, "LUNG_CANCER", "entropy")
print("Best attribute according to custom method:", best_attribute)

# Calculate entropy for the 'AGE' variable
entropy_values = calculate_entropy_for_age(df, "LUNG_CANCER")
print("Entropy values for different split points of AGE:", entropy_values)

# Compare
X = df.drop(columns=["LUNG_CANCER"])
y = df["LUNG_CANCER"]

# Iterate over all columns in X
for col in X.columns:
    if X[col].dtype == 'object':  # Check if the column is object
        X[col] = le.fit_transform(X[col])  # Fit and transform

clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X, y)

# Get the first split attribute
first_split_attribute = X.columns[clf.tree_.feature[0]]
print("First attribute chosen by DecisionTreeClassifier:", first_split_attribute)
# Out:
# Best attribute according to custom method: AGE
# Entropy values for different split points of AGE: [0.5312781889262875, 0.5419170987184109, 0.5449207038264753, 0.5403639290746973, 0.5441094553701515, 0.5468141979237555, 0.5469524459514221, 0.5403704036482998, 0.5462869713766704, 0.5436734290872279, 0.536762076328995, 0.5435642756886613, 0.5468750690614211, 0.5436483829226163, 0.5464872109219885, 0.5464505835454, 0.5413412632922332, 0.5372452975058454, 0.5433445318000694, 0.546912418896242, 0.5456500440544474, 0.5467598956437505, 0.5452315708244128, 0.5467661472988791, 0.5329683752468372, 0.5443885594150157, 0.5453678251213374, 0.5389240730616076, 0.5418654189325439, 0.530898768138415, 0.5443048663916832, 0.545575446617381, 0.5458932337609829, 0.5372452975058453, 0.5449269188381558, 0.5431019275031438, 0.5449269188381558, 0.5469617378366156, 0.5428368567425824]
# First attribute chosen by DecisionTreeClassifier: ALLERGY

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import math

# %%
# entropy function
def entropy(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return -np.sum(probabilities * np.log2(probabilities + 1e-9))

# %%
# Gini function
def gini(y):
    value, counts = np.unique(y, return_counts=True)
    probabilities = counts / counts.sum()
    return 1 - np.sum(probabilities ** 2)

# %%
# best attribute to split on
def calculate_best_split(X, y, impurity_measure):
    best_gain = -1
    best_attribute = None
    base_impurity = entropy(y) if impurity_measure == 'entropy' else gini(y)

    for attribute in X.columns:
        values = X[attribute].unique()
        split_impurity = 0
        for value in values:
            subset_y = y[X[attribute] == value]
            if len(subset_y) == 0:
                continue
            if impurity_measure == 'entropy':
                split_impurity += (len(subset_y) / len(y)) * entropy(subset_y)
            else:
                split_impurity += (len(subset_y) / len(y)) * gini(subset_y)

        gain = base_impurity - split_impurity
        if gain > best_gain:
            best_gain = gain
            best_attribute = attribute

    return best_attribute

# %%
#  entropy for a quantitative variable
def calculate_entropy_for_age(df, target):
    overall = len(df)
    entropies = []
    feature = 'AGE'
    vals = df[feature].unique()

    for val in vals:
        entropy_value = 0

        # Left split
        left = df[df[feature] <= val][[feature, target]]
        props = left[target].value_counts(normalize=True)
        weight = len(left) / overall
        for prop in props:
            entropy_value -= weight * prop * math.log2(prop + 1e-9)

        # Right split
        right = df[df[feature] > val][[feature, target]]
        props = right[target].value_counts(normalize=True)
        weight = len(right) / overall
        for prop in props:
            entropy_value -= weight * prop * math.log2(prop + 1e-9)

        entropies.append(entropy_value)

    return entropies

# %%
# Attribute selection main
def Attribute_selection_method(task, dataset, target_variable, impurity_measure=None):
    if task not in ["regression", "classification"]:
        raise ValueError("Task must be either 'regression' or 'classification'.")

    # features and target variable
    X = dataset.drop(columns=[target_variable])
    y = dataset[target_variable]

    if task == "classification" and impurity_measure is None:
        raise ValueError("For classification tasks, 'impurity_measure' must be specified.")

    # best attribute based on the impurity
    best_attribute = calculate_best_split(X, y, impurity_measure)

    return best_attribute

# %%
# Load data
url = "https://raw.githubusercontent.com/jhbellingrath/CS-290-Classwork/refs/heads/main/data/survey%20lung%20cancer.csv"
df = pd.read_csv(url)

# %%
# LabelEncoder
le = LabelEncoder()

# %%
# target variable
df["LUNG_CANCER"] = le.fit_transform(df["LUNG_CANCER"])

# %%
# find the best attribute for classification
best_attribute = Attribute_selection_method("classification", df, "LUNG_CANCER", "entropy")
print("Best attribute according to custom method:", best_attribute)
# Out:
# Best attribute according to custom method: AGE

# %%
# Calculate entropy for the 'AGE' variable
entropy_values = calculate_entropy_for_age(df, "LUNG_CANCER")
print("Entropy values for different split points of AGE:", entropy_values)
# Out:
# Entropy values for different split points of AGE: [0.5312781889262875, 0.5419170987184109, 0.5449207038264753, 0.5403639290746973, 0.5441094553701515, 0.5468141979237555, 0.5469524459514221, 0.5403704036482998, 0.5462869713766704, 0.5436734290872279, 0.536762076328995, 0.5435642756886613, 0.5468750690614211, 0.5436483829226163, 0.5464872109219885, 0.5464505835454, 0.5413412632922332, 0.5372452975058454, 0.5433445318000694, 0.546912418896242, 0.5456500440544474, 0.5467598956437505, 0.5452315708244128, 0.5467661472988791, 0.5329683752468372, 0.5443885594150157, 0.5453678251213374, 0.5389240730616076, 0.5418654189325439, 0.530898768138415, 0.5443048663916832, 0.545575446617381, 0.5458932337609829, 0.5372452975058453, 0.5449269188381558, 0.5431019275031438, 0.5449269188381558, 0.5469617378366156, 0.5428368567425824]

# %%
# Compare
X = df.drop(columns=["LUNG_CANCER"])
y = df["LUNG_CANCER"]

# %%
# Iterate over all columns in X
for col in X.columns:
    if X[col].dtype == 'object':  # Check if the column is object
        X[col] = le.fit_transform(X[col])  # Fit and transform

# %%
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# Get the first split attribute
first_split_attribute = X.columns[clf.tree_.feature[0]]
print("First attribute chosen by DecisionTreeClassifier:", first_split_attribute)
# Out:
# First attribute chosen by DecisionTreeClassifier: ALLERGY
